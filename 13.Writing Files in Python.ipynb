# %% [markdown]
# ## 13. Writing Files in Python
#
#  * `File handling` means working with files stored on the computer using Python.
#
#
# ### With Python We can:
#  * `Create a file`
#  * `Read data from a file`
#  * `Write data to a file`
#  * `Append data to a file`
#  * `Delete a file`
#
#
#  * _Files are stored on `secondary storage(hard disk)` and help us save data permanently._
#
# Example uses:
#  * Saving user data
#  * Storing logs
#  * Writing reports
#  * Saving configuration settings

# %% [markdown]
# ### 2. Basic Steps for Writing a File
#
# * __When Writing to a file, Python follows `three main steps`__
#
# * 1️⃣ Open the file
#
# * 2️⃣ Write data into the file
#
# * 3️⃣ Close the file

# %%
fileName = "C:\\Users\\User\\Desktop\\data.txt"
file = open(fileName,'w') 
file.write("Hello world")
file.close()

# %%
x = open(fileName,'r')
y = x.read()
y
# Out:
# 'Hello world'

# %%
fileName = "data.txt"
file = open(fileName,'w') 
file.write("Hello world")
file.close()

# %% [markdown]
# Notes:
#
# * open() --> Open the file
# * "data.txt" --> file name
# * "w" --> Write mode
# * write() --> Writes data
# * close() --> closes the file

# %% [markdown]
# # 3. File Opening Modes (very Important)
# ---
# |Mode|Meaning|Description|
# |---|---|---|
# |"r"|Read|Opens file for reading only.|
# |"w"|Write|Creates file or overwrites existing file|
# |"a"|Append|Adds data at end of the file|
# |"x"|Creates|Creates new file, error if exists|
# |"b"|Binary|Used for images/files|
# |"t"|Text|Default mode

# %% [markdown]
# * open("file.txt","r")   # read
# * open("file.txt","w")   # write
# * open("file.txt","a")   # append

# %% [markdown]
# ## 4. Writing Data to a file
#
# write() writes one string to a file.

# %%
file = open("C:\\Users\\User\\Desktop\\data.txt",'w')

file.write("Name: Ankit\n")
file.write("Age:22\n")
file.write("Course:Python\n")

file.close()

# %% [markdown]
# ### 5. Writing Multiple Lines(Writelines)
#
# writelines() writes multiple lines at once.

# %%
file = open("C:\\Users\\User\\Desktop\\data.txt","w")


lines = [
    "Python is a Programming languages.\n",
    "File Handling\n",
    "Object Oriented Programming\n"
]

file.writelines(lines)
file.close()

# %%
x = open("C:\\Users\\User\\Desktop\\data.txt",'r')

y = x.read()
print(y)
# Out:
# Python is a Programming languages.
# File Handling
# Object Oriented Programming

# %% [markdown]
# ### 6. Using "with" statement(Best Practice)
#
# Instead of manually closing files, Python provices with statement.
#
# Benefits:
# * Automatically closes the file.
# * safer
# * Cleaner code

# %%
fileName = "C:\\Users\\User\\Desktop\\data.txt"

with open(fileName,'w') as file:
    file.write("Welcome to Python file Handling")

# %%
with open(fileName,'r') as f:
    print(f.read())
# Out:
# Welcome to Python file Handling

# %% [markdown]
# ### 7. Append Data to file
#
#
# Append means add new data without deleting old data.
#
#
# Mode used: "a"

# %%
fileName = "C:\\Users\\User\\Desktop\\data.txt"


with open(fileName,'a') as f:
    f.write("\nNew User logged in\n")

# %%
name = input("Enter user name: ")

age = input("Enter user age: ")

course = input("Enter Course:")

with open(fileName,'a') as file:
    file.write("------------------------------\n")
    file.write("Name:"+name+"\n")
    file.write("Age:"+age+"\n")
    file.write("Course:"+course+"\n")
    file.write("--------------------------------\n")
print("Data Saved Successfully!")
# Out:
# Enter user name:  vishal
# Enter user age:  25
# Enter Course: java
# Data Saved Successfully!

# %%
# Write a file 10 lines and count total number of words 

lines = [
    "Python is a powerful programming language\n",
    "It is widely used in DevOps and automation\n",
    "Python is easy to learn and understand\n",
    "Many developers use Python for scripting\n",
    "Automation testing also uses Python\n",
    "Cloud engineers use Python for automation\n",
    "Python supports object oriented programming\n",
    "It has many libraries for different tasks\n",
    "Learning Python improves problem solving skills\n",
    "Practice Python programs daily for improvement\n"
]

with open("data.txt", "w") as file:
    file.writelines(lines)

print("10 lines written successfully")

word_count = 0

with open("data.txt", "r") as file:
    for line in file:
        words = line.split()  
        word_count += len(words)

print("Total number of words:", word_count)
# Out:
# 10 lines written successfully
# Total number of words: 62

# %%
# total number of words, total number of characters and total of white spaces
# total numbers, total special characters

# condition
# loop
fileName = "C:\\Users\\User\\Desktop\\NursaryRhymes.txt"

with open(fileName,"r") as f:
    
    char1=0
    for char in f:
        
        for i in char:
            if i in " ":
                continue
            char1+=1
            # print(i)
    print("total char:",char1)



total words:
total chars:
total speces:
# Out:
# total char: 517

# %%
fileName= input("Enter your filename: ")
fullFileName="C:\\Users\\User\\Desktop\\"+fileName+".txt"
# print(fullFileName)


with open(fullFileName,'w') as f:
    linesNum=int(input("Enter Number of lines to write: "))
    count=0
    vow=0
    cons=0
    vowelsChar = []
    consonentChar=[]
    for con in range(1,linesNum+1):
        content=input("Enter your content here:")
        vowels = "aeiouAEIOU"
        for j in content:
            count=count+1
            # print(count)
            if j in vowels:
                vow+=1
                vowelsChar.append(j)
            else:
                cons+=1
                consonentChar.append(j)
        # content1 = str(con),".",content
        content1 = f"{con}.{content}"
        f.write(content1)
        f.write("\n")
    countChar= f"Total Number of Characters:{count}"
    vowChar = f"Total Number of Vowels:{vow},{vowelsChar}"
    consChar=f"Total Number of Consonent:{cons},{consonentChar}"
    
    f.write("--------------Details of File------------------\n")
    f.write(countChar)
    f.write("\n")
    f.write(vowChar)
    f.write("\n")
    f.write(consChar)
# Out:
# Enter your filename:  data
# Enter Number of lines to write:  3
# Enter your content here: apple
# Enter your content here: banana
# Enter your content here: carrot

# %%
# Ask the user to enter a file name (without extension)
fileName = input("Enter your filename: ")

# Create the full path of the file by joining folder path + filename + .txt extension
fullFileName = "C:\\Users\\User\\Desktop\\" + fileName + ".txt"

# Open the file in write ('w') mode.
# If the file already exists, it will be overwritten.
# 'as f' creates a file object named f
with open(fullFileName, 'w') as f:

    # Ask user how many lines they want to write in the file
    linesNum = int(input("Enter Number of lines to write: "))

    # Variable to count total characters
    count = 0

    # Variable to count vowels
    vow = 0

    # Variable to count consonants
    cons = 0

    # List to store all vowel characters found in the text
    vowelsChar = []

    # List to store all consonant characters found in the text
    consonentChar = []

    # Loop from 1 to number of lines entered by user
    for con in range(1, linesNum + 1):

        # Take content for each line from the user
        content = input("Enter your content here:")

        # String containing all vowels (both lowercase and uppercase)
        vowels = "aeiouAEIOU"

        # Loop through every character in the entered content
        for j in content:

            # Increase total character count
            count = count + 1

            # Check if the character is a vowel
            if j in vowels:
                # Increase vowel count
                vow += 1

                # Store the vowel character in vowel list
                vowelsChar.append(j)

            else:
                # If not vowel, count it as consonant
                cons += 1

                # Store the consonant character in consonant list
                consonentChar.append(j)

        # Create line content with line number
        # Example: 1.Hello World
        content1 = f"{con}.{content}"

        # Write the line into the file
        f.write(content1)

        # Move to next line in file
        f.write("\n")

    # Create summary string for total characters
    countChar = f"Total Number of Characters:{count}"

    # Create summary string for vowels and show vowel list
    vowChar = f"Total Number of Vowels:{vow},{vowelsChar}"

    # Create summary string for consonants and show consonant list
    consChar = f"Total Number of Consonent:{cons},{consonentChar}"

    # Write heading for file details
    f.write("--------------Details of File------------------\n")

    # Write total characters information
    f.write(countChar)

    # Move to next line
    f.write("\n")

    # Write vowel details
    f.write(vowChar)

    # Move to next line
    f.write("\n")

    # Write consonant details
    f.write(consChar)

# %%
filename = 'C:\\Users\\anilp\\OneDrive\\Desktop\\test3.txt'
count = 0

with open(filename, 'r') as f:
    c = f.readlines()

    for i in c:
        count += 1
    print(f'Total existing lines: {count}')

with open(filename, 'a') as f:
    line = int(input('enter number of lines: '))

    for i in range(count + 1, count + 1 + line):
        value = input(f'enter values of {i} line: ')
        f.write(f'{i}. {value}\n')

with open(filename, 'r') as f:
    c = f.read()
    print(c)

# %%
###  Write a file "data.txt" and take data from user count total characters and numbers and special characters.

fileName = "data"

fullFileName = "C:\\Users\\User\\Desktop\\"+fileName+".txt"
print(fullFileName)

with open(fullFileName,'w') as f:
    charCount = 0
    ascii_letters = 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'
    digits = '0123456789'
    punctuation = '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
    digitCounts=0
    puncCount=0
    upperCase = 0
    lowerCase = 0
    while True:
        conteint = input("Enter your content: ")
        if content.lower() == "stop":
            break
        for i in content:
            charCount+=1
            if i in digits:
                digitCounts+=1
            elif i in punctuation:
                puncCount+=1
            elif i>=chr(65) and i<=chr(90):
                upperCase+=1
                # print(i)
            elif i>=chr(97) and i<=chr(122):
                lowerCase+=1
                # print(i)
       
        f.write(content)
        f.write("\n")
        
    totalchar = f"Total Printable Characters is:{charCount}\n"
    specialChar = f"Total Special Characters is: {puncCount}\n"
    digitsCount = f"Total Digits: {digitCounts}\n"
    upperCase = f"Total UpperCase:{upperCase}\n"
    lowerCase = f"Total LowerCase:{lowerCase}\n"
    f.write("-----------Details of File---------------------\n")
    f.write(totalchar)
    
    f.write(specialChar)
    f.write(digitsCount)
    f.write(upperCase)
    f.write(lowerCase)
    print("File Generated Successfully!")
    print(charCount)
# Out:
# C:\Users\User\Desktop\data.txt
# Enter your content:  apple
# Enter your content:  BanaNA
# Enter your content:  123455
# Enter your content:  !@#$%^
# Enter your content:  stop
# File Generated Successfully!
# 23

# %%
import string

# %%
help(string)
# Out:
# Help on module string:
#
# NAME
#     string - A collection of string constants.
#
# MODULE REFERENCE
#     https://docs.python.org/3.13/library/string.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Public module variables:
#
#     whitespace -- a string containing all ASCII whitespace
#     ascii_lowercase -- a string containing all ASCII lowercase letters
#     ascii_uppercase -- a string containing all ASCII uppercase letters
#     ascii_letters -- a string containing all ASCII letters
#     digits -- a string containing all ASCII decimal digits
#     hexdigits -- a string containing all ASCII hexadecimal digits
#     octdigits -- a string containing all ASCII octal digits
# ...

# %%
chr(65)
# Out:
# 'A'

# %%
chr(90)
# Out:
# 'Z'

# %%
chr(97)
# Out:
# 'a'

# %%
chr(122)
# Out:
# 'z'
